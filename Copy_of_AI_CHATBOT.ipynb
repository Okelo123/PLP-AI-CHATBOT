# %% [markdown]
# <a href="https://colab.research.google.com/github/Okelo123/PLP-AI-CHATBOT/blob/main/Copy_of_AI_CHATBOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BRIAN JUMA

# Step 1: Bot name and personality
bot_name = "CryptoBuddy"
bot_personality = "friendly"

# Step 2: Greeting function
def greet_user():
    print(f"👋 Hello! I'm {bot_name}, your friendly crypto companion!")
    print("🚀 I can help you with crypto prices, explain blockchain terms, and more.")
    print("💬 What would you like to know today?")

# Step 3: Get input from the user
def get_user_input():
    return input("You: ")

# Step 4: Main function to run the chatbot
def main():
    greet_user()
    user_message = get_user_input()
    print(f"{bot_name}: I'm still learning, but I'll do my best to help with '{user_message}'!")

# Run the chatbot
if __name__ == "__main__":
    main()
# Out:
# 👋 Hello! I'm CryptoBuddy, your friendly crypto companion!
# 🚀 I can help you with crypto prices, explain blockchain terms, and more.
# 💬 What would you like to know today?
# You: tell me about crypto
# CryptoBuddy: I'm still learning, but I'll do my best to help with 'tell me about crypto'!

# %%
# 📈 Rule-Based Logic - Profitability Focus
# 👤 Coded by: [Carolyne Katilo]

#  Crypto dataset
crypto_db = {
    "Bitcoin": {
        "price_trend": "rising",
        "market_cap": "high",
        "energy_use": "high",
        "sustainability_score": 3/10
    },
    "Ethereum": {
        "price_trend": "stable",
        "market_cap": "high",
        "energy_use": "medium",
        "sustainability_score": 6/10
    },
    "Cardano": {
        "price_trend": "rising",
        "market_cap": "medium",
        "energy_use": "low",
        "sustainability_score": 8/10
    }
}

# Function for profitable recommendation
def recommend_profitable_crypto(data):
    for coin, info in data.items():
        if info["price_trend"] == "rising" and info["market_cap"] == "high":
            return f"{coin} is trending up and has a strong market presence. It might be a solid choice for investment! 🚀"
    return "No highly profitable cryptocurrencies found at the moment."

#  Chat interaction
user_input = input("Ask me about profitable cryptos: ").lower()

if "profit" in user_input or "growth" in user_input:
    print(recommend_profitable_crypto(crypto_db))
else:
    print("Try asking about profitability or growth opportunities!")
# Out:
# Ask me about profitable cryptos: which crypto is most profitable?
# Bitcoin is trending up and has a strong market presence. It might be a solid choice for investment! 🚀

# %%
# ♻️ Rule-Based Logic - Sustainability Focus
# 👤 Coded by: [Raphael Kang'eri]

# Function for sustainable recommendation
def recommend_sustainable_crypto(data):
    sustainable_coins = []
    for coin, info in data.items():
        if info["energy_use"] == "low" and info["sustainability_score"] > 7/10:
            sustainable_coins.append((coin, info["sustainability_score"]))

    if sustainable_coins:
        # Sort by highest sustainability score
        best_coin = max(sustainable_coins, key=lambda x: x[1])
        return f"🌱 {best_coin[0]} is the most sustainable choice with a score of {int(best_coin[1]*10)}/10! It's a great pick for eco-conscious investing."
    else:
        return "⚠️ No crypto meets the top sustainability criteria at the moment."

# Chat interaction for sustainability
user_input_sustainability = input("Ask me about green or eco-friendly cryptos: ").lower()

if "sustainable" in user_input_sustainability or "eco" in user_input_sustainability or "green" in user_input_sustainability:
    print(recommend_sustainable_crypto(crypto_db))
else:
    print("Try asking about eco-friendly or sustainable crypto options!")
# Out:
# Ask me about green or eco-friendly cryptos: which crypto is the most ecofreiendly?
# 🌱 Cardano is the most sustainable choice with a score of 8/10! It's a great pick for eco-conscious investing.

# %%
# ==============================
# Data Handling - Coded by Caroline Wanjiru
# ==============================

crypto_db = {
    "Bitcoin": {
        "price_trend": "rising",
        "market_cap": "high",
        "energy_use": "high",
        "sustainability_score": 4,
        "launch_year": 2009
    },
    "Ethereum": {
        "price_trend": "rising",
        "market_cap": "high",
        "energy_use": "medium",
        "sustainability_score": 6,
        "launch_year": 2015
    },
    "Cardano": {
        "price_trend": "stable",
        "market_cap": "medium",
        "energy_use": "low",
        "sustainability_score": 9,
        "launch_year": 2017
    },
    "Solana": {
        "price_trend": "rising",
        "market_cap": "medium",
        "energy_use": "low",
        "sustainability_score": 8,
        "launch_year": 2020
    }
}

# Add recent performance metrics
for coin in crypto_db:
    crypto_db[coin]["recent_performance"] = {
        "1_month": "+5.2%",
        "3_months": "+18.7%"
    }

# ==============================
# Data Preview & Analysis Output
# ==============================
print("\n" + "="*50)
print("💾 CRYPTO DATASET LOADED SUCCESSFULLY")
print("="*50 + "\n")

print("🔍 Dataset Preview:")
print("-"*40)
for i, (coin, data) in enumerate(crypto_db.items(), 1):
    print(f"{i}. {coin.upper()}")
    print(f"   • Trend: {data['price_trend'].capitalize()}")
    print(f"   • Market Cap: {data['market_cap'].capitalize()}")
    print(f"   • Energy: {data['energy_use'].capitalize()}")
    print(f"   • Sustainability: {data['sustainability_score']}/10")
    print(f"   • Recent Performance: {data['recent_performance']['1_month']} (1M)")
    print("-"*40)

print("\n📊 Quick Statistics:")
print(f"• Total Cryptos Tracked: {len(crypto_db)}")
green_coins = [coin for coin in crypto_db if crypto_db[coin]['sustainability_score'] >= 7]
print(f"• Eco-Friendly Options: {len(green_coins)} ({', '.join(green_coins)})")
# Out:
# ...
# 💾 CRYPTO DATASET LOADED SUCCESSFULLY
# ...
#
# 🔍 Dataset Preview:
# ----------------------------------------
# 1. BITCOIN
#    • Trend: Rising
#    • Market Cap: High
#    • Energy: High
#    • Sustainability: 4/10
#    • Recent Performance: +5.2% (1M)
# ----------------------------------------
# 2. ETHEREUM
#    • Trend: Rising
#    • Market Cap: High
#    • Energy: Medium
#    • Sustainability: 6/10
#    • Recent Performance: +5.2% (1M)
# ----------------------------------------
# 3. CARDANO
#    • Trend: Stable
#    • Market Cap: Medium
#    • Energy: Low
#    • Sustainability: 9/10
#    • Recent Performance: +5.2% (1M)
# ----------------------------------------
# 4. SOLANA
#    • Trend: Rising
#    • Market Cap: Medium
#    • Energy: Low
#    • Sustainability: 8/10
#    • Recent Performance: +5.2% (1M)
# ----------------------------------------
#
# 📊 Quick Statistics:
# • Total Cryptos Tracked: 4
# • Eco-Friendly Options: 2 (Cardano, Solana)

# %%
# ==============================
# Testing & Final Touches - Coded by Caroline Wanjiru
# ==============================

# Define placeholder functions for now
def handle_profit_queries(query):
    """Placeholder function to handle profit-related queries."""
    if "rising" in query or "profit" in query:
        # This is a simplified response for testing
        return "Looking for rising coins? Consider Bitcoin, Ethereum, or Solana."
    return None

def handle_sustainability_queries(query):
    """Placeholder function to handle sustainability-related queries."""
    if "green" in query or "sustainable" in query or "eco" in query:
        # This is a simplified response for testing
        return "Interested in green options? Check out Cardano and Solana."
    return None


def run_tests():
    """Automated test cases with visual output"""
    print("\n" + "="*50)
    print("🧪 RUNNING SYSTEM TESTS")
    print("="*50)

    test_cases = [
        ("Which coin is rising?", "profit", ["Bitcoin", "Ethereum", "Solana"]),
        ("Show me green coins", "sustainability", ["Cardano", "Solana"]),
        ("What should I buy?", "unknown", []),
        ("exit", "exit", [])
    ]

    for query, query_type, expected in test_cases:
        print(f"\nTEST CASE: '{query}'")
        print("-"*40)

        if query_type == "exit":
            print("✅ Exit command recognized")
            continue

        # Ensure the functions are called correctly
        response = handle_profit_queries(query) if query_type == "profit" else handle_sustainability_queries(query)

        if not response:
            print("⚠️ No response generated" if query_type != "unknown" else "✅ Correctly ignored unknown query")
        else:
            # Simplified check for now
            passed = all(coin in response for coin in expected)
            print(f"{'✅ PASS' if passed else '❌ FAIL'} - Response: {response}")

def main():
    """Enhanced main conversation flow"""
    print("\n" + "="*50)
    print(f"🚀 WELCOME TO {bot_name.upper()}!")
    print("="*50)
    print("Type 'examples' to see query samples or 'exit' to quit\n")

    run_tests()  # Show test results on startup

    while True:
        try:
            user_input = input("\nYour query: ").strip()

            if user_input.lower() == 'exit':
                print(f"\n{bot_name}: 🔒 Session ended. Always verify with CoinGecko!")
                break
            elif user_input.lower() == 'examples':
                print("\n💡 Try these queries:")
                print("- 'Which crypto is rising?'")
                print("- 'Show me sustainable coins'")
                print("- 'Compare energy usage'")
                continue

            # Process queries
            response = handle_profit_queries(user_input) or \
                      handle_sustainability_queries(user_input) or \
                      "I can analyze:\n • Profit trends 💹\n • Sustainability ♻️\nTry: 'rising coins' or 'green cryptos'"

            print(f"\n{bot_name}: {response}")

        except Exception as e:
            print(f"\n{bot_name}: ❗ Error processing request - please try again")

# ==============================
# Launch the Chatbot
# ==============================
if __name__ == "__main__":
    main()
# Out:
# ...
# 🚀 WELCOME TO CRYPTOBUDDY!
# ...
# Type 'examples' to see query samples or 'exit' to quit
#
#
# ...
# 🧪 RUNNING SYSTEM TESTS
# ...
#
# TEST CASE: 'Which coin is rising?'
# ----------------------------------------
# ✅ PASS - Response: Looking for rising coins? Consider Bitcoin, Ethereum, or Solana.
#
# TEST CASE: 'Show me green coins'
# ----------------------------------------
# ✅ PASS - Response: Interested in green options? Check out Cardano and Solana.
#
# TEST CASE: 'What should I buy?'
# ----------------------------------------
# ✅ Correctly ignored unknown query
#
# TEST CASE: 'exit'
# ----------------------------------------
# ✅ Exit command recognized
#
# CryptoBuddy: I can analyze:
#  • Profit trends 💹
#  • Sustainability ♻️
# Try: 'rising coins' or 'green cryptos'
#
# CryptoBuddy: Looking for rising coins? Consider Bitcoin, Ethereum, or Solana.
